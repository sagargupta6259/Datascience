# %% [markdown]
# FUNCTION

# %%
# def fun_name(parameters):
  #body of the function
  def add_(a,b):
    return(a+b)
# Out:
#   File "/tmp/ipykernel_1572/2473569116.py", line 3
#     def add_(a,b):
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# LAMBDA FUNCTION

# %%
x=lambda a,b : b * a
print(x(2,3))
# Out:
# 6

# %% [markdown]
# STRING----------start---------->

# %%
st=""
print(len(st))

st = "sagar"
st1 = st.upper()
print(st1)
# Out:
# 0
# SAGAR

# %% [markdown]
# question prractice

# %%
st = "sagar"
st1 = st.upper()
print(st1)


st = "SAGAR"
st2=st.lower()
print(st2)

St="sagar gupta"
st3=st.title()
print(st3)

st="sagar gupta"
st4=st.capitalize()
print(st4)
# Out:
# SAGAR
# sagar
# Sagar
# Sagar gupta

# %%
st="sagar kumar gupta"
# strip ---- age or piche se space hatata hai
st2=st.strip()
print(st2)
# Out:
# sagar kumar gupta

# %%
first_name="sagar"
last_name=" kumar gupta"
first_name=first_name.strip()
last_name=last_name.strip()

print(first_name+" "+last_name)
# Out:
# sagar kumar gupta

# %%
a="today "
b=" weather "
c="is good "
cap=a.capitalize()
low=c.lower()
rep=c.replace("good","bad")


print(cap.strip()+"  "+b.strip()+"  "+rep.strip())
# Out:
# Today  weather  is bad

# %%
st="sagar gupta"
s=st.find("gupta")
print(s)

start=st.startswith("sagar")
print(start)

end=st.endswith("gupta")
print(end)
# Out:
# 6
# False
# True

# %% [markdown]
# index (slicing)

# %%
s="hello world"
print(s[:5])
# Out:
# hello

# %% [markdown]
# <----SET------->

# %%
st={2,2,23,2,1}
print(st)
# Out:
# {1, 2, 23}

# %% [markdown]
# DICTIONARY

# %%
dct={
    "name":["sagar","rahul","aman","raj"],
    "age":20,
    "occupation":"student",
    "class":10,
    "rool no":71,
}

# print(dct["name"][0])
dct["id"]=12
print(dct)
del dct["name"]
print(dct)
# Out:
# {'name': ['sagar', 'rahul', 'aman', 'raj'], 'age': 20, 'occupation': 'student', 'class': 10, 'rool no': 71, 'id': 12}
# {'age': 20, 'occupation': 'student', 'class': 10, 'rool no': 71, 'id': 12}
